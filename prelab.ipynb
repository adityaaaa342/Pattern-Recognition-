# %% [markdown]
# <a href="https://colab.research.google.com/github/adityaaaa342/Pattern-Recognition-/blob/main/prelab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pattern Recognition Pre-Lab

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import cv2
import tensorflow as tf
from sklearn.datasets import load_iris

# Library Verification
print("===== Library Verification =====")
print("NumPy Version:", np.__version__)
print("Pandas Version:", pd.__version__)
print("Scikit-Learn Version:", sklearn.__version__)
print("OpenCV Version:", cv2.__version__)
print("TensorFlow Version:", tf.__version__)

# Dataset Handling
print("\n===== Iris Dataset =====")
iris = load_iris()

df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

print(df.head())

# Dataset Information
print("\nDataset Shape:", df.shape)

# Visualization
plt.figure(figsize=(8, 5))
plt.scatter(
    df['sepal length (cm)'],
    df['sepal width (cm)']
)

plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Iris Dataset Scatter Plot')
plt.grid(True)

plt.show()
# Out:
# ===== Library Verification =====
# NumPy Version: 2.0.2
# Pandas Version: 2.2.2
# Scikit-Learn Version: 1.6.1
# OpenCV Version: 4.13.0
# TensorFlow Version: 2.20.0
#
# ===== Iris Dataset =====
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# Dataset Shape: (150, 4)
